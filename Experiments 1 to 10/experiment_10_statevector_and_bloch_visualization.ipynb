# %% [markdown]
# # 23CSE463 – Quantum Computing | Worksheet 2
#
# **Course:** 23CSE463 – Quantum Computing
# **Experiment:** Worksheet-2 / Ex. No. 2
# **Title:** Study and Visualization of Single-Qubit States Using the Bloch Sphere
# **Name:** C S Deeraj
# **Register No.:** CH.SC.U4CSE24106
# **Date:** 18/06/2026

# %% [markdown]
# ## Program 10
#
# ### AIM
# Generate the state vector of a single-qubit quantum circuit and visualize its corresponding Bloch Sphere representation using Qiskit.
#
# ### APPARATUS REQUIRED
# - Python 3.10 or above
# - Qiskit Quantum Computing Framework
# - Jupyter Notebook / VS Code
# - Internet connection for package installation and documentation access

# %% [markdown]
# ### PROCEDURE
# 1. Import the required Qiskit libraries and visualization modules.
# 2. Create a single-qubit quantum circuit initialized in |0⟩.
# 3. Apply the required quantum gate(s).
# 4. Generate the statevector.
# 5. Visualize the state using the Bloch Sphere.
# 6. Observe and analyze the resulting state.

# %% [markdown]
# ### PROGRAM CODE

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# %%
qc = QuantumCircuit(1)
qc.ry(np.pi / 3, 0)
qc.rz(np.pi / 4, 0)
state = Statevector.from_instruction(qc)

print("Circuit:")
display(qc.draw("mpl"))
print("\nStatevector:")
print(state)
print("\nBloch Sphere representation:")
plot_bloch_multivector(state)
plt.show()

# %% [markdown]
# ### OUTPUT / OBSERVATION
# The code above generates the quantum circuit, statevector, and Bloch Sphere visualization.
#
# ### RESULT
# The generated pure single-qubit state is represented by a point on the surface of the Bloch Sphere.
#
# **Experiment completed successfully.**
